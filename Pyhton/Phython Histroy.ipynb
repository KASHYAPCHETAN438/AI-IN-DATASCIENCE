# %% [markdown]
#
#
# # **INTRODUCTION TO PYTHON**
#
#
# - Software : Collection of program
#
# - Program : Collection of instructuion
#
#
# <br>
#
#
# ## Types of software
#
# ### System
# - These are essesintal software to run computer
#
# - ex. operating system , compiler , loder , Linker , Driver
#
# -  For the design system software we need to learn c , c++ , vc++ , vc++ .net
#
#
# ### Application
# - The software which is design to full fill the requirement of
#               specific user.
#
# - These are also known as Desktop , Window software and we ues it after the install
# - These software contain two part
#
#      - Fornt-End : It is uesed for creating the front pages of application
#      - ex. VB, D2K , VB.NET , these language are used only the design the fornt pages of application
#
#      - Back-End : It is used to store the data. It known as database
#                         ex. oracle , mysql , DB2
#
# <br>
#
# ### Web Application
#
# - Those software which are internet based.
#
# - To run these types of software we need internet for the accessing because these software connect with server.
#       All the web of the world is known as Web Application software
#
# - To create these types of software we need to learn HTML , CSS , PHP ,JAVASCRIPT ,ASP,NET so other language are aviable on market
#
# <br>
#
# ### Device
# - It is also known as Moble device.
#
#   - java  --> is used for making the andriod application
#   - Swift --> is used for making the IOS application
#
# - AI / IOT : Airtificail inteligence is the branch of computer science it's compeletly depands on python
#
# <br>
#
#
#
#
#
# **PYTHON**
#
# - By the help of python we can create Desktop application , Web based application ,and AI
#
#
# - But we can not create System software and Mobile based application
#
#
# - It's used both function and method
#
# <br>
#
#
# ### **Define Python in one line** :
# - Python is open source , free ware , procedure + function + OOP's , platform independant language
#
# <br>
#
# ### **Open source** :
#  - All method are openly aviable any one can see the Source code of python
#
# <br>
#
# ### PYTHON save file with these extenion
#
#  - .py-->   it's has source code of python
#
#  - .pyc-->  it's has compiled code / Bytecode
#  - .ipynb --> it's for google coloab or jupyter note book.
#
# - **Free Ware** : It's freely aviable for download
#
#
# - **Plantform Independant** : Write one and run anywhere. Python don't create exe. file
#
#
# - **Plantform Dependant** : If a language is created excueted file then it's platform dependant language
#
#
# <br>
#
#
# **Feature of python**
#
#   - Simple and easy to learn
#   - Free & Open source
#   - High level language
#   - Function & OOPS language
#   - Expandable
#   - Portable
#   - Interpreterd language
#   - Embaded
#   - Rich Library
#
#
# <br>
#
# ### **History of Python**
#
#    - Guddo Van Rossum
#    - 1989--> Bita version
#    - 1991--> Official version
#
# ### **Limitation of Python**
#
# - Mobile application
# - performance wise python is low because it's interpreter
# - But now python use jit complier that's it's enchance the performance
#
#
# **Flavor of Python**
#
# - CPython--> For C application
# - JPython--> For Java application
# - RubyPython--> For Ruby application
# - IronPython--> For .Net application
# - AnacondaPython--> For Big data application
# - StackPython--> For multithreaded application
# - PYPY--> Python for Python

# %% [markdown]
# ## **IDLE**
# - Integrated Development Learning Enviorment
# - when we have all softewr intergrated to each other for the performing
# - excutiom is known as IDLE
#
# <br>
#
# ## **Statements :** Commands which we use to write python program
# - example
#
#    - print()
#    - input()
#    - If Else
#    -  for loop
#    - while loop
#    - break, continue , pass
#    - def
#    - try - except
#    - with satement
#    -  import
#
# <br>
#
# ## **Indentation**
# - **Space which we use in python while writing a code for make the code easier to read**
#
# - python don't use the curley bracket so in python indentation is most
#       important for the define the scope of any function and loop
#
#
# <br>
#
# - **Comments :** It's use for hide the some line of code and other things
#
#     -   `#` --> It's used for single line of comment
