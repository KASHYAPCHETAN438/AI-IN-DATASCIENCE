# %% [markdown]
# ![1785438591883.png](data:image/png;base64,...)

# %% [markdown]
# # **TUPLE**
#
# * Heterogeneous:
#   * Can store multiple data types.
#
# * Contiguous:
#   * Elements are stored in contiguous memory.
#
# * Order:
#   * Maintains insertion order.
#
# * Immutable:
#   * Cannot change, add, or remove elements after creation.
#
# * Duplicates Allowed:
#   * Same value can appear multiple times.
#
# * Not Unique:
#   * Values don’t need to be unique.
#
#           Syntax: (item1, item2, ...)
#
# <br>

# %% [markdown]
# <br>
#
# ## When to use Tuple
#
# - Coordinates
# - RGB Values
# - DataBase Records
#
# - Gps Location

# %% [markdown]
# # Why Tuple is Faster
#
# ### Reason
# - Immutable
# - Fixed Sized
# - Optimized Memory Allocation

# %% [markdown]
# <br>
#
# ### Tupple is Hashable
# - A hashable object is an object whose hash value never changes during its lifetime.

# %%
print(hash(10))                   #
print(hash("Python"))

# %%
# we can define a list with tuple(1,2,3) constructor , and a=(12,5,4,7)


print("\n#============Tuple==================\n")

t=(1,2,3,1)           # Tuple Type ()  it can store multiple types of data , allowed duplicate
# t[1]=5              # tuple is immutable we can't change , it don't have any method like add() , append()

print()
print(t)
print(type(t))



y=(1,1,"Delhi",2.4,[1,2,3])
print()
print(y)
print(type(y))



print("\n\n\n tuple(1,2,3,8 )---> Give error because tuple is a method which accepts only one argument")


t=tuple([1,2,3])                # create tuple using tuple() constructor
print("\n",t)

# %% [markdown]
# # Tuple Method

# %%
t = (1,2,3,2)
t.index(2)   # 1
t.count(2)   # 2
# Out:
# 2
